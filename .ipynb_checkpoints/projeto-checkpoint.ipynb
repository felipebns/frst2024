# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import seaborn as sns
import networkx as nx
import ast
import scipy
from pyvis.network import Network
from scipy import stats
from tqdm.auto import tqdm

# %% [markdown]
# # PREPARO DOS DADOS

# %%
df = pd.read_excel('dados_brutos.xlsx')

# %%
orgs = df['organization_id']
users = df['user']
org_u = set(orgs)
dic_userPorOrg = {}
for i,org in enumerate(org_u):
    df_aux = df.loc[(df["organization_id"] == org),:]
    user_aux = df_aux["user"]
    dic_userPorOrg[org] = len(set(user_aux))

# %%
organizations = []
n_users = []
for k,v in dic_userPorOrg.items():
    organizations.append(k)
    n_users.append(v)

df_userPorOrg = pd.DataFrame({
    'organization_id': organizations,
    'N_users': n_users
})

df_userPorOrg = df_userPorOrg.sort_values(ascending=False, by='N_users').reset_index(drop=True)

# %%
dic_pathPorOrg = {}
paths_list_t = []
orgs = df_userPorOrg["organization_id"]

for org in orgs:
    path_aux = df.loc[(df["organization_id"] == org),(["path_actions"])]
    paths_list_u = []
    lista = [ast.literal_eval(paths[0]) for paths in path_aux.values]
    paths_list_u.extend((set(lista[0]))) #extend adiciona cada elemento da lista em paths_list
    paths_list_t.extend((lista[0])) #extend adiciona cada elemento da lista em paths_list_u
    dic_pathPorOrg[org] = (set(paths_list_u))

df_paths = pd.DataFrame()
df_paths['Count'] = pd.Series(paths_list_t).value_counts().values
df_paths['Actions'] = pd.Series(paths_list_t).value_counts().keys()

# %%
action_d = {}
novo_path_list = [0]*len(paths_list_t)
cont = 0
for i,path in enumerate(paths_list_t):
    if path not in action_d.keys():
        action_d[path] = cont
        cont += 1

for i,path in enumerate(paths_list_t):
    novo_path_list[i] = action_d[path]

# %% [markdown]
# # ANÁLISE EXPLORATÓRIA

# %%
mean = np.mean(novo_path_list)
median = np.median(novo_path_list)
mode = stats.mode(novo_path_list)
dp = np.std(novo_path_list)
print(f'Mean: {mean}, median: {median}, mode: {mode}, dp: {dp}')
# Out:
# Mean: 5.084269662921348, median: 3.0, mode: ModeResult(mode=array([3]), count=array([643])), dp: 6.716224078984249

# %%
plt.figure(figsize=(20,6))

plt.subplot(1,3,1)
plt.bar(df_paths['Actions'], df_paths['Count'], edgecolor='black', linewidth=1.2, alpha=0.7)
plt.xticks(rotation=90)
plt.title('Contagem Actions - Bar')

plt.subplot(1,3,2)
plt.hist(paths_list_t, edgecolor='black', linewidth=1.2, alpha=0.7, density=True)
plt.xticks(rotation=90)
plt.title('Contagem Actions - Hist')

plt.subplot(1,3,3)
plt.boxplot(df_paths['Count'])
plt.title('Contagem Actions - Box')
plt.show()

# %%
organizations2 = []
paths = []
for k,v in dic_pathPorOrg.items():
    organizations2.append(k)
    paths.append(v)

df_pathPorOrg = pd.DataFrame({
    'organization_id': organizations2,
    'Paths': paths
})

# %%
df_pathPorOrg.head(20)
# Out:
#                          organization_id  \
# 0   4f3e63d2-43f8-4886-addc-9ce039eab5f1
# 1   4adb5f9b-f50a-4957-a7e3-94c3452d877c
# 2   c81fa8b0-52c0-4a31-abb7-6776a76cc9c8
# 3   d3400673-a5b2-4914-bf57-ce98dc710603
# 4   347ceb13-8656-4ed0-b080-c6cfb5528b25
# 5   9e3e7a95-c6f5-4b6f-b189-8f33e45ee425
# 6   50ca2381-2d91-4d7e-8300-bb625d5cb97f
# 7   abba8235-15bd-4285-90b4-104e9308013e
# 8   c8c88852-b101-4b47-aaca-4cee45368c9f
# 9   6019ee26-09c3-422e-8c25-0abe878d1a73
# 10  071250db-e54d-4d3a-a179-d1546ba79c63
# 11  e41e98b5-a36e-4028-b7a6-e534aef3f280
# 12  0780e259-6a78-4fcd-b8f3-689cc21c7ecf
# 13  c5b694a6-ecb4-427e-b517-b74e76b00861
# 14  98f3a814-35d8-4bbe-8e1e-45796305b021
# 15  f45c0788-7955-436a-a4a9-b400464ef36d
# 16  6042fbe2-b932-40bf-8fe9-f0f7dc870a49
# 17  cbdf1fac-5e6a-4d10-9aae-570fda653d2a
# 18  1ef5051a-b5d5-4b85-bca6-93868a8a4b73
# 19  7da5a3d1-5507-4619-b494-613641b6fa82
#
#                                                 Paths
# 0   {click em trilhas-lxp, acessar conteúdos em ví...
# 1   {acessar meus desafios-hall, acessar conteúdos...
# 2   {click em trilhas-lxp, acessar meus desafios-h...
# 3   {handleOpenPrezziModalSRG-hall, handleOpenModa...
# 4                                         {home-hall}
# 5   {handle-busc-semantica-hall, acessar meus desa...
# 6   {acessar meus desafios-hall, acessar conteúdos...
# 7   {onboarding-to Step 3, onboarding-to Step 2, c...
# 8   {acessar meus desafios-hall, modal-SRG, handle...
# 9   {click em trilhas-lxp, acessar conteúdos em ví...
# 10  {click em trilhas-lxp, acessar conteúdos em ví...
# 11  {onboardingAdmin-skip, acessar conteúdos em ví...
# 12  {onboarding-to Community, criar conteúdo-lxp, ...
# 13  {click em trilhas-lxp, acessar conteúdos em ví...
# 14  {acessar meus desafios-hall, handleViewDesafio...
# 15  {onboarding-skip, onboarding-to Profile, acess...
# 16  {click em trilhas-lxp, acessar conteúdos em ví...
# 17  {criar conteúdo-lxp, acessar conteúdos em víde...
# 18  {onboarding-to Step 3, onboarding-to Step 2, c...
# 19  {onboardingAdmin-to Step 3, onboardingAdmin-to...

# %%
x = np.linspace(0,30,1001)
fx = (stats.norm.pdf(x, loc=mean, scale=dp))

# %%
plt.hist(novo_path_list, density=True)
plt.plot(x, fx, color='red')
plt.show()

# %%
testando = df['path_actions']
actions = pd.DataFrame({ 'from':[], 'to':[], 'value':[]})
from_ = list(actions['from'])
to_ = list(actions['to'])
value_ = []
counts = {}
saidas_totais = {}

for lista in testando:
    lista_x = ast.literal_eval(lista)
    len_lista = len(lista_x)
    for i,e in enumerate(ast.literal_eval(lista)):
        if i + 1 < len_lista:
            # print(e)
            # print(ast.literal_eval(lista)[i+1])
            # print('---')
            e_1 = ast.literal_eval(lista)[i+1]

            from_.append(e)
            to_.append(e_1)

            if (e,e_1) not in counts.keys():
                counts[(e,e_1)] = 1
            else:
                counts[(e,e_1)] += 1

            if e not in saidas_totais.keys():
                saidas_totais[e] = 1
            else:
                saidas_totais[e] += 1
actions['from'] = from_
actions['to'] = to_


for lista in testando:
    lista_x = ast.literal_eval(lista)
    len_lista = len(lista_x)
    for i,e in enumerate(ast.literal_eval(lista)):
        if i + 1 < len_lista:
            # print(e)
            # print(ast.literal_eval(lista)[i+1])
            # print('---')
            e_1 = ast.literal_eval(lista)[i+1]
            value_.append(counts[(e, e_1)])
actions['value'] = value_

# %%
actions
# Out:
#                                  from                              to  value
# 0                           home-hall      acessar meus desafios-hall   1415
# 1          acessar meus desafios-hall       handleViewDesafioSRG-hall    533
# 2           handleViewDesafioSRG-hall                       home-hall    157
# 3                           home-hall  acessar conteúdos em vídeo-lxp   1441
# 4      acessar conteúdos em vídeo-lxp            click em trilhas-lxp   1639
# ...                               ...                             ...    ...
# 33714  acessar conteúdos em vídeo-lxp            click em trilhas-lxp   1639
# 33715            click em trilhas-lxp                       home-hall    330
# 33716                       home-hall  acessar conteúdos em vídeo-lxp   1441
# 33717  acessar conteúdos em vídeo-lxp            click em trilhas-lxp   1639
# 33718            click em trilhas-lxp  acessar conteúdos em vídeo-lxp    587
#
# [33719 rows x 3 columns]

# %%
G = nx.from_pandas_edgelist(actions,
                            source="from",
                            target="to",
                            edge_attr="value",
                            create_using= nx.Graph())

# %%
plt.figure(figsize=(10,10))
pos = nx.kamada_kawai_layout(G)
nx.draw(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos=pos)
plt.show()

# %%
net = Network(notebook=True, width="1000px", height="700px", bgcolor="#222222", font_color="white")

net.from_nx(G)
net.show("Markov.html")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4056\3551517321.py in <module>
# ----> 1 net = Network(notebook=True, width="1000px", height="700px", bgcolor="#222222", font_color="white", cdn_resources='inline')
#       2
#       3 net.from_nx(G)
#       4 net.show("Markov.html")
#
# c:\Users\Felipe\anaconda3\lib\site-packages\pyvis\network.py in __init__(self, height, width, directed, notebook, neighborhood_highlight, select_menu, filter_menu, bgcolor, font_color, layout, heading, cdn_resources)
#      89         self.select_menu = select_menu
#      90         self.filter_menu = filter_menu
# ---> 91         assert cdn_resources in ["local", "in_line", "remote"], "cdn_resources not in [local, in_line, remote]."
#      92         # path is the root template located in the template_dir
#      93         self.path = "template.html"
#
# AssertionError: cdn_resources not in [local, in_line, remote].

# %%
plt.figure(figsize=(20,15))
G = nx.DiGraph(directed=True)
# G.add_edges_from([actions[0:500], 'from', 'to'])
h = nx.from_pandas_edgelist(actions[0:500], 'from', 'to')
G.add_nodes_from(h.nodes)
G.add_edges_from(h.edges)
pos = nx.random_layout(G)

nx.draw(G, pos, with_labels=True, edge_color='lightGreen', node_size=120, cmap=plt.cm.Blues, width=1, arrows=True) #add cores e frequencia
plt.show()

# %%
# # libraries
# import pandas as pd
# import numpy as np
# import networkx as nx
# import matplotlib.pyplot as plt
 
# # Build a dataframe with your connections
# df = pd.DataFrame({ 'from':['A', 'B', 'C','A'], 'to':['D', 'A', 'E','C'], 'value':[1, 10, 5, 5]})
 
# # Build your graph
# G=nx.from_pandas_edgelist(df, 'from', 'to', create_using=nx.Graph() )
 
# # Custom the nodes:
# nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_color=df['value'], width=10.0, edge_cmap=plt.cm.Blues)

# %% [markdown]
# # CRIANDO MATRIX DE TRANSIÇÃO

# %%
total = sum(counts.values())
counts_freq = counts
for k,v in counts_freq.items():
    counts_freq[k] = v/saidas_totais[k[0]]

# %%
matrix = pd.DataFrame()
for k in action_d.keys():
    matrix[k] = 0
    matrix.loc[k] = 0

for k,v in counts_freq.items():
    matrix.loc[k[0], k[1]] = v

# %%
print(matrix.loc['home-hall', 'onboarding-skip']) #linha, coluna
# Out:
# 0.0046048537647790915

# %%
matrix = matrix.fillna(0)
matrix
# Out:
#                                     home-hall  acessar conteúdos em vídeo-lxp  \
# home-hall                            0.582078                        0.179340
# acessar conteúdos em vídeo-lxp       0.055984                        0.559124
# click em trilhas-lxp                 0.319149                        0.567698
# acessar meus desafios-hall           0.074232                        0.026924
# onboarding-skip                      0.124812                        0.001504
# handleOpenModalSRG-hall              0.015260                        0.001795
# handleDeleteDesafioSRG-hall          0.000000                        0.000000
# handleConfirmDeleteDesafioSRG-hall   0.333333                        0.111111
# handleOpenPrezziModalSRG-hall        0.018617                        0.000000
# handle-busc-semantica-hall           0.141414                        0.070707
# onboarding-to Step 2                 0.019048                        0.000000
# onboarding-to Step 3                 0.116162                        0.000000
# onboarding-to Community              0.639241                        0.107595
# modal-SRG                            0.016179                        0.007745
# handleCloseDesafioModalSRG-hall      0.141042                        0.060991
# ver canais-lxp                       0.147436                        0.762821
# onboardingAdmin-skip                 0.885542                        0.036145
# criar conteúdo-lxp                   0.592593                        0.333333
# handleViewDesafioSRG-hall            0.220506                        0.088483
# onboarding-to Profile                0.268817                        0.290323
# onboardingAdmin-to Step 2            0.014493                        0.000000
# onboardingAdmin-to Step 3            0.130435                        0.000000
# seta carrossel canais-lxp            0.015267                        0.068702
# onboardingAdmin-to Step 4            0.903226                        0.016129
# home-hall-manager                    0.435294                        0.188235
# handleSkipPrezziSRG-hall             0.005556                        0.000000
# onboarding-to Step 1                 0.000000                        0.000000
# onboarding-to Challenge              0.022222                        0.044444
# clickNotification-hall               0.275316                        0.047468
# botão carrossel meus desafios-hall   0.055172                        0.037931
# handleEditDetaisSRG-hall             0.231884                        0.014493
# click em módulos-lxp                 0.116279                        0.813953
# handleCancelDeleteDesafioSRG-hall    0.166667                        0.000000
#
#                                     click em trilhas-lxp  \
# home-hall                                       0.000000
# acessar conteúdos em vídeo-lxp                  0.294097
# click em trilhas-lxp                            0.010638
# acessar meus desafios-hall                      0.000000
# onboarding-skip                                 0.000000
# handleOpenModalSRG-hall                         0.000000
# handleDeleteDesafioSRG-hall                     0.000000
# handleConfirmDeleteDesafioSRG-hall              0.000000
# handleOpenPrezziModalSRG-hall                   0.000000
# handle-busc-semantica-hall                      0.003367
# onboarding-to Step 2                            0.000000
# onboarding-to Step 3                            0.000000
# onboarding-to Community                         0.000000
# modal-SRG                                       0.000172
# handleCloseDesafioModalSRG-hall                 0.000000
# ver canais-lxp                                  0.000000
# onboardingAdmin-skip                            0.000000
# criar conteúdo-lxp                              0.000000
# handleViewDesafioSRG-hall                       0.000000
# onboarding-to Profile                           0.000000
# onboardingAdmin-to Step 2                       0.000000
# onboardingAdmin-to Step 3                       0.000000
# seta carrossel canais-lxp                       0.137405
# onboardingAdmin-to Step 4                       0.000000
# home-hall-manager                               0.000000
# handleSkipPrezziSRG-hall                        0.000000
# onboarding-to Step 1                            0.000000
# onboarding-to Challenge                         0.000000
# clickNotification-hall                          0.000000
# botão carrossel meus desafios-hall              0.000000
# handleEditDetaisSRG-hall                        0.000000
# click em módulos-lxp                            0.000000
# handleCancelDeleteDesafioSRG-hall               0.000000
#
#                                     acessar meus desafios-hall  \
# home-hall                                             0.176105
# acessar conteúdos em vídeo-lxp                        0.024762
# click em trilhas-lxp                                  0.063830
# acessar meus desafios-hall                            0.589747
# onboarding-skip                                       0.009023
# handleOpenModalSRG-hall                               0.012567
# handleDeleteDesafioSRG-hall                           0.000000
# handleConfirmDeleteDesafioSRG-hall                    0.125000
# handleOpenPrezziModalSRG-hall                         0.021277
# handle-busc-semantica-hall                            0.124579
# onboarding-to Step 2                                  0.000000
# onboarding-to Step 3                                  0.030303
# onboarding-to Community                               0.101266
# modal-SRG                                             0.099828
# handleCloseDesafioModalSRG-hall                       0.116900
# ver canais-lxp                                        0.032051
# onboardingAdmin-skip                                  0.030120
# criar conteúdo-lxp                                    0.037037
# handleViewDesafioSRG-hall                             0.477528
# onboarding-to Profile                                 0.301075
# onboardingAdmin-to Step 2                             0.000000
# onboardingAdmin-to Step 3                             0.000000
# seta carrossel canais-lxp                             0.022901
# onboardingAdmin-to Step 4                             0.000000
# home-hall-manager                                     0.129412
# handleSkipPrezziSRG-hall                              0.044444
# onboarding-to Step 1                                  0.000000
# onboarding-to Challenge                               0.355556
# clickNotification-hall                                0.139241
# botão carrossel meus desafios-hall                    0.037931
# handleEditDetaisSRG-hall                              0.507246
# click em módulos-lxp                                  0.023256
# handleCancelDeleteDesafioSRG-hall                     0.000000
#
#                                     onboarding-skip  handleOpenModalSRG-hall  \
# home-hall                                  0.004605                 0.007716
# acessar conteúdos em vídeo-lxp             0.001435                 0.000179
# click em trilhas-lxp                       0.010638                 0.000967
# acessar meus desafios-hall                 0.002890                 0.050198
# onboarding-skip                            0.533835                 0.012030
# handleOpenModalSRG-hall                    0.000000                 0.018851
# handleDeleteDesafioSRG-hall                0.000000                 0.000000
# handleConfirmDeleteDesafioSRG-hall         0.013889                 0.055556
# handleOpenPrezziModalSRG-hall              0.000000                 0.515957
# handle-busc-semantica-hall                 0.003367                 0.000000
# onboarding-to Step 2                       0.057143                 0.000000
# onboarding-to Step 3                       0.267677                 0.010101
# onboarding-to Community                    0.063291                 0.018987
# modal-SRG                                  0.001033                 0.030981
# handleCloseDesafioModalSRG-hall            0.003812                 0.208386
# ver canais-lxp                             0.000000                 0.000000
# onboardingAdmin-skip                       0.000000                 0.012048
# criar conteúdo-lxp                         0.000000                 0.000000
# handleViewDesafioSRG-hall                  0.005618                 0.147472
# onboarding-to Profile                      0.021505                 0.000000
# onboardingAdmin-to Step 2                  0.000000                 0.000000
# onboardingAdmin-to Step 3                  0.000000                 0.000000
# seta carrossel canais-lxp                  0.000000                 0.000000
# onboardingAdmin-to Step 4                  0.000000                 0.000000
# home-hall-manager                          0.000000                 0.000000
# handleSkipPrezziSRG-hall                   0.000000                 0.000000
# onboarding-to Step 1                       0.066667                 0.000000
# onboarding-to Challenge                    0.022222                 0.288889
# clickNotification-hall                     0.003165                 0.000000
# botão carrossel meus desafios-hall         0.000000                 0.037931
# handleEditDetaisSRG-hall                   0.043478                 0.159420
# click em módulos-lxp                       0.000000                 0.000000
# handleCancelDeleteDesafioSRG-hall          0.000000                 0.166667
#
#                                     handleDeleteDesafioSRG-hall  \
# home-hall                                              0.000000
# acessar conteúdos em vídeo-lxp                         0.000000
# click em trilhas-lxp                                   0.000000
# acessar meus desafios-hall                             0.007454
# onboarding-skip                                        0.000000
# handleOpenModalSRG-hall                                0.001795
# handleDeleteDesafioSRG-hall                            0.000000
# handleConfirmDeleteDesafioSRG-hall                     0.097222
# handleOpenPrezziModalSRG-hall                          0.000000
# handle-busc-semantica-hall                             0.000000
# onboarding-to Step 2                                   0.000000
# onboarding-to Step 3                                   0.000000
# onboarding-to Community                                0.000000
# modal-SRG                                              0.000172
# handleCloseDesafioModalSRG-hall                        0.027954
# ver canais-lxp                                         0.000000
# onboardingAdmin-skip                                   0.000000
# criar conteúdo-lxp                                     0.000000
# handleViewDesafioSRG-hall                              0.000000
# onboarding-to Profile                                  0.000000
# onboardingAdmin-to Step 2                              0.000000
# onboardingAdmin-to Step 3                              0.000000
# seta carrossel canais-lxp                              0.000000
# onboardingAdmin-to Step 4                              0.000000
# home-hall-manager                                      0.000000
# handleSkipPrezziSRG-hall                               0.000000
# onboarding-to Step 1                                   0.000000
# onboarding-to Challenge                                0.000000
# clickNotification-hall                                 0.000000
# botão carrossel meus desafios-hall                     0.013793
# handleEditDetaisSRG-hall                               0.000000
# click em módulos-lxp                                   0.000000
# handleCancelDeleteDesafioSRG-hall                      0.666667
#
#                                     handleConfirmDeleteDesafioSRG-hall  \
# home-hall                                                     0.000000
# acessar conteúdos em vídeo-lxp                                0.000000
# click em trilhas-lxp                                          0.000000
# acessar meus desafios-hall                                    0.000000
# onboarding-skip                                               0.000000
# handleOpenModalSRG-hall                                       0.000000
# handleDeleteDesafioSRG-hall                                   0.932584
# handleConfirmDeleteDesafioSRG-hall                            0.000000
# handleOpenPrezziModalSRG-hall                                 0.000000
# handle-busc-semantica-hall                                    0.000000
# onboarding-to Step 2                                          0.000000
# onboarding-to Step 3                                          0.000000
# onboarding-to Community                                       0.000000
# modal-SRG                                                     0.000000
# handleCloseDesafioModalSRG-hall                               0.000000
# ver canais-lxp                                                0.000000
# onboardingAdmin-skip                                          0.000000
# criar conteúdo-lxp                                            0.000000
# handleViewDesafioSRG-hall                                     0.000000
# onboarding-to Profile                                         0.000000
# onboardingAdmin-to Step 2                                     0.000000
# onboardingAdmin-to Step 3                                     0.000000
# seta carrossel canais-lxp                                     0.000000
# onboardingAdmin-to Step 4                                     0.000000
# home-hall-manager                                             0.000000
# handleSkipPrezziSRG-hall                                      0.000000
# onboarding-to Step 1                                          0.000000
# onboarding-to Challenge                                       0.000000
# clickNotification-hall                                        0.000000
# botão carrossel meus desafios-hall                            0.000000
# handleEditDetaisSRG-hall                                      0.000000
# click em módulos-lxp                                          0.000000
# handleCancelDeleteDesafioSRG-hall                             0.000000
#
#                                     handleOpenPrezziModalSRG-hall  \
# home-hall                                                0.002614
# acessar conteúdos em vídeo-lxp                           0.000000
# click em trilhas-lxp                                     0.000000
# acessar meus desafios-hall                               0.039550
# onboarding-skip                                          0.010526
# handleOpenModalSRG-hall                                  0.000000
# handleDeleteDesafioSRG-hall                              0.000000
# handleConfirmDeleteDesafioSRG-hall                       0.138889
# handleOpenPrezziModalSRG-hall                            0.013298
# handle-busc-semantica-hall                               0.000000
# onboarding-to Step 2                                     0.000000
# onboarding-to Step 3                                     0.010101
# onboarding-to Community                                  0.000000
# modal-SRG                                                0.000172
# handleCloseDesafioModalSRG-hall                          0.060991
# ver canais-lxp                                           0.000000
# onboardingAdmin-skip                                     0.003012
# criar conteúdo-lxp                                       0.018519
# handleViewDesafioSRG-hall                                0.001404
# onboarding-to Profile                                    0.000000
# onboardingAdmin-to Step 2                                0.000000
# onboardingAdmin-to Step 3                                0.000000
# seta carrossel canais-lxp                                0.000000
# onboardingAdmin-to Step 4                                0.016129
# home-hall-manager                                        0.000000
# handleSkipPrezziSRG-hall                                 0.000000
# onboarding-to Step 1                                     0.000000
# onboarding-to Challenge                                  0.177778
# clickNotification-hall                                   0.000000
# botão carrossel meus desafios-hall                       0.044828
# handleEditDetaisSRG-hall                                 0.000000
# click em módulos-lxp                                     0.000000
# handleCancelDeleteDesafioSRG-hall                        0.000000
#
#                                     handle-busc-semantica-hall  ...  \
# home-hall                                             0.008339  ...
# acessar conteúdos em vídeo-lxp                        0.002512  ...
# click em trilhas-lxp                                  0.002901  ...
# acessar meus desafios-hall                            0.002586  ...
# onboarding-skip                                       0.000000  ...
# handleOpenModalSRG-hall                               0.000000  ...
# handleDeleteDesafioSRG-hall                           0.000000  ...
# handleConfirmDeleteDesafioSRG-hall                    0.000000  ...
# handleOpenPrezziModalSRG-hall                         0.000000  ...
# handle-busc-semantica-hall                            0.639731  ...
# onboarding-to Step 2                                  0.000000  ...
# onboarding-to Step 3                                  0.000000  ...
# onboarding-to Community                               0.006329  ...
# modal-SRG                                             0.001205  ...
# handleCloseDesafioModalSRG-hall                       0.006353  ...
# ver canais-lxp                                        0.006410  ...
# onboardingAdmin-skip                                  0.003012  ...
# criar conteúdo-lxp                                    0.000000  ...
# handleViewDesafioSRG-hall                             0.011236  ...
# onboarding-to Profile                                 0.000000  ...
# onboardingAdmin-to Step 2                             0.000000  ...
# onboardingAdmin-to Step 3                             0.000000  ...
# seta carrossel canais-lxp                             0.000000  ...
# onboardingAdmin-to Step 4                             0.000000  ...
# home-hall-manager                                     0.000000  ...
# handleSkipPrezziSRG-hall                              0.000000  ...
# onboarding-to Step 1                                  0.000000  ...
# onboarding-to Challenge                               0.000000  ...
# clickNotification-hall                                0.012658  ...
# botão carrossel meus desafios-hall                    0.000000  ...
# handleEditDetaisSRG-hall                              0.000000  ...
# click em módulos-lxp                                  0.000000  ...
# handleCancelDeleteDesafioSRG-hall                     0.000000  ...
#
#                                     onboardingAdmin-to Step 4  \
# home-hall                                            0.000124
# acessar conteúdos em vídeo-lxp                       0.000000
# click em trilhas-lxp                                 0.000000
# acessar meus desafios-hall                           0.000000
# onboarding-skip                                      0.000000
# handleOpenModalSRG-hall                              0.000000
# handleDeleteDesafioSRG-hall                          0.000000
# handleConfirmDeleteDesafioSRG-hall                   0.000000
# handleOpenPrezziModalSRG-hall                        0.000000
# handle-busc-semantica-hall                           0.000000
# onboarding-to Step 2                                 0.000000
# onboarding-to Step 3                                 0.000000
# onboarding-to Community                              0.000000
# modal-SRG                                            0.000000
# handleCloseDesafioModalSRG-hall                      0.000000
# ver canais-lxp                                       0.000000
# onboardingAdmin-skip                                 0.000000
# criar conteúdo-lxp                                   0.000000
# handleViewDesafioSRG-hall                            0.000000
# onboarding-to Profile                                0.000000
# onboardingAdmin-to Step 2                            0.101449
# onboardingAdmin-to Step 3                            0.753623
# seta carrossel canais-lxp                            0.000000
# onboardingAdmin-to Step 4                            0.032258
# home-hall-manager                                    0.000000
# handleSkipPrezziSRG-hall                             0.000000
# onboarding-to Step 1                                 0.000000
# onboarding-to Challenge                              0.000000
# clickNotification-hall                               0.000000
# botão carrossel meus desafios-hall                   0.000000
# handleEditDetaisSRG-hall                             0.000000
# click em módulos-lxp                                 0.000000
# handleCancelDeleteDesafioSRG-hall                    0.000000
#
#                                     home-hall-manager  \
# home-hall                                    0.007841
# acessar conteúdos em vídeo-lxp               0.001794
# click em trilhas-lxp                         0.000967
# acessar meus desafios-hall                   0.001065
# onboarding-skip                              0.000000
# handleOpenModalSRG-hall                      0.000000
# handleDeleteDesafioSRG-hall                  0.000000
# handleConfirmDeleteDesafioSRG-hall           0.000000
# handleOpenPrezziModalSRG-hall                0.000000
# handle-busc-semantica-hall                   0.003367
# onboarding-to Step 2                         0.000000
# onboarding-to Step 3                         0.000000
# onboarding-to Community                      0.000000
# modal-SRG                                    0.000344
# handleCloseDesafioModalSRG-hall              0.001271
# ver canais-lxp                               0.006410
# onboardingAdmin-skip                         0.003012
# criar conteúdo-lxp                           0.000000
# handleViewDesafioSRG-hall                    0.001404
# onboarding-to Profile                        0.000000
# onboardingAdmin-to Step 2                    0.000000
# onboardingAdmin-to Step 3                    0.000000
# seta carrossel canais-lxp                    0.000000
# onboardingAdmin-to Step 4                    0.032258
# home-hall-manager                            0.176471
# handleSkipPrezziSRG-hall                     0.000000
# onboarding-to Step 1                         0.000000
# onboarding-to Challenge                      0.000000
# clickNotification-hall                       0.000000
# botão carrossel meus desafios-hall           0.000000
# handleEditDetaisSRG-hall                     0.014493
# click em módulos-lxp                         0.000000
# handleCancelDeleteDesafioSRG-hall            0.000000
#
#                                     handleSkipPrezziSRG-hall  \
# home-hall                                           0.000000
# acessar conteúdos em vídeo-lxp                      0.000000
# click em trilhas-lxp                                0.000000
# acessar meus desafios-hall                          0.002434
# onboarding-skip                                     0.000000
# handleOpenModalSRG-hall                             0.008079
# handleDeleteDesafioSRG-hall                         0.000000
# handleConfirmDeleteDesafioSRG-hall                  0.000000
# handleOpenPrezziModalSRG-hall                       0.414894
# handle-busc-semantica-hall                          0.000000
# onboarding-to Step 2                                0.000000
# onboarding-to Step 3                                0.000000
# onboarding-to Community                             0.000000
# modal-SRG                                           0.000000
# handleCloseDesafioModalSRG-hall                     0.001271
# ver canais-lxp                                      0.000000
# onboardingAdmin-skip                                0.000000
# criar conteúdo-lxp                                  0.000000
# handleViewDesafioSRG-hall                           0.000000
# onboarding-to Profile                               0.000000
# onboardingAdmin-to Step 2                           0.000000
# onboardingAdmin-to Step 3                           0.000000
# seta carrossel canais-lxp                           0.000000
# onboardingAdmin-to Step 4                           0.000000
# home-hall-manager                                   0.000000
# handleSkipPrezziSRG-hall                            0.000000
# onboarding-to Step 1                                0.000000
# onboarding-to Challenge                             0.022222
# clickNotification-hall                              0.000000
# botão carrossel meus desafios-hall                  0.000000
# handleEditDetaisSRG-hall                            0.000000
# click em módulos-lxp                                0.000000
# handleCancelDeleteDesafioSRG-hall                   0.000000
#
#                                     onboarding-to Step 1  \
# home-hall                                       0.000000
# acessar conteúdos em vídeo-lxp                  0.000000
# click em trilhas-lxp                            0.000000
# acessar meus desafios-hall                      0.000000
# onboarding-skip                                 0.012030
# handleOpenModalSRG-hall                         0.000000
# handleDeleteDesafioSRG-hall                     0.000000
# handleConfirmDeleteDesafioSRG-hall              0.000000
# handleOpenPrezziModalSRG-hall                   0.000000
# handle-busc-semantica-hall                      0.000000
# onboarding-to Step 2                            0.009524
# onboarding-to Step 3                            0.025253
# onboarding-to Community                         0.000000
# modal-SRG                                       0.000000
# handleCloseDesafioModalSRG-hall                 0.000000
# ver canais-lxp                                  0.000000
# onboardingAdmin-skip                            0.000000
# criar conteúdo-lxp                              0.000000
# handleViewDesafioSRG-hall                       0.000000
# onboarding-to Profile                           0.000000
# onboardingAdmin-to Step 2                       0.000000
# onboardingAdmin-to Step 3                       0.000000
# seta carrossel canais-lxp                       0.000000
# onboardingAdmin-to Step 4                       0.000000
# home-hall-manager                               0.000000
# handleSkipPrezziSRG-hall                        0.000000
# onboarding-to Step 1                            0.000000
# onboarding-to Challenge                         0.000000
# clickNotification-hall                          0.000000
# botão carrossel meus desafios-hall              0.000000
# handleEditDetaisSRG-hall                        0.000000
# click em módulos-lxp                            0.000000
# handleCancelDeleteDesafioSRG-hall               0.000000
#
#                                     onboarding-to Challenge  \
# home-hall                                          0.000000
# acessar conteúdos em vídeo-lxp                     0.000000
# click em trilhas-lxp                               0.000000
# acessar meus desafios-hall                         0.000000
# onboarding-skip                                    0.037594
# handleOpenModalSRG-hall                            0.000000
# handleDeleteDesafioSRG-hall                        0.000000
# handleConfirmDeleteDesafioSRG-hall                 0.000000
# handleOpenPrezziModalSRG-hall                      0.000000
# handle-busc-semantica-hall                         0.000000
# onboarding-to Step 2                               0.000000
# onboarding-to Step 3                               0.085859
# onboarding-to Community                            0.006329
# modal-SRG                                          0.000000
# handleCloseDesafioModalSRG-hall                    0.000000
# ver canais-lxp                                     0.000000
# onboardingAdmin-skip                               0.000000
# criar conteúdo-lxp                                 0.000000
# handleViewDesafioSRG-hall                          0.000000
# onboarding-to Profile                              0.000000
# onboardingAdmin-to Step 2                          0.000000
# onboardingAdmin-to Step 3                          0.000000
# seta carrossel canais-lxp                          0.000000
# onboardingAdmin-to Step 4                          0.000000
# home-hall-manager                                  0.000000
# handleSkipPrezziSRG-hall                           0.000000
# onboarding-to Step 1                               0.000000
# onboarding-to Challenge                            0.044444
# clickNotification-hall                             0.000000
# botão carrossel meus desafios-hall                 0.000000
# handleEditDetaisSRG-hall                           0.000000
# click em módulos-lxp                               0.000000
# handleCancelDeleteDesafioSRG-hall                  0.000000
#
#                                     clickNotification-hall  \
# home-hall                                         0.014935
# acessar conteúdos em vídeo-lxp                    0.001077
# click em trilhas-lxp                              0.008704
# acessar meus desafios-hall                        0.001977
# onboarding-skip                                   0.000000
# handleOpenModalSRG-hall                           0.000000
# handleDeleteDesafioSRG-hall                       0.000000
# handleConfirmDeleteDesafioSRG-hall                0.000000
# handleOpenPrezziModalSRG-hall                     0.000000
# handle-busc-semantica-hall                        0.006734
# onboarding-to Step 2                              0.000000
# onboarding-to Step 3                              0.000000
# onboarding-to Community                           0.018987
# modal-SRG                                         0.001377
# handleCloseDesafioModalSRG-hall                   0.003812
# ver canais-lxp                                    0.000000
# onboardingAdmin-skip                              0.003012
# criar conteúdo-lxp                                0.000000
# handleViewDesafioSRG-hall                         0.014045
# onboarding-to Profile                             0.010753
# onboardingAdmin-to Step 2                         0.000000
# onboardingAdmin-to Step 3                         0.000000
# seta carrossel canais-lxp                         0.000000
# onboardingAdmin-to Step 4                         0.000000
# home-hall-manager                                 0.000000
# handleSkipPrezziSRG-hall                          0.000000
# onboarding-to Step 1                              0.000000
# onboarding-to Challenge                           0.000000
# clickNotification-hall                            0.515823
# botão carrossel meus desafios-hall                0.006897
# handleEditDetaisSRG-hall                          0.014493
# click em módulos-lxp                              0.000000
# handleCancelDeleteDesafioSRG-hall                 0.000000
#
#                                     botão carrossel meus desafios-hall  \
# home-hall                                                     0.000000
# acessar conteúdos em vídeo-lxp                                0.000000
# click em trilhas-lxp                                          0.000000
# acessar meus desafios-hall                                    0.014147
# onboarding-skip                                               0.000000
# handleOpenModalSRG-hall                                       0.000000
# handleDeleteDesafioSRG-hall                                   0.000000
# handleConfirmDeleteDesafioSRG-hall                            0.013889
# handleOpenPrezziModalSRG-hall                                 0.005319
# handle-busc-semantica-hall                                    0.000000
# onboarding-to Step 2                                          0.000000
# onboarding-to Step 3                                          0.000000
# onboarding-to Community                                       0.000000
# modal-SRG                                                     0.000172
# handleCloseDesafioModalSRG-hall                               0.031766
# ver canais-lxp                                                0.000000
# onboardingAdmin-skip                                          0.000000
# criar conteúdo-lxp                                            0.000000
# handleViewDesafioSRG-hall                                     0.002809
# onboarding-to Profile                                         0.000000
# onboardingAdmin-to Step 2                                     0.000000
# onboardingAdmin-to Step 3                                     0.000000
# seta carrossel canais-lxp                                     0.000000
# onboardingAdmin-to Step 4                                     0.000000
# home-hall-manager                                             0.000000
# handleSkipPrezziSRG-hall                                      0.000000
# onboarding-to Step 1                                          0.000000
# onboarding-to Challenge                                       0.000000
# clickNotification-hall                                        0.000000
# botão carrossel meus desafios-hall                            0.610345
# handleEditDetaisSRG-hall                                      0.014493
# click em módulos-lxp                                          0.000000
# handleCancelDeleteDesafioSRG-hall                             0.000000
#
#                                     handleEditDetaisSRG-hall  \
# home-hall                                           0.000124
# acessar conteúdos em vídeo-lxp                      0.000000
# click em trilhas-lxp                                0.000000
# acessar meus desafios-hall                          0.007301
# onboarding-skip                                     0.000000
# handleOpenModalSRG-hall                             0.000898
# handleDeleteDesafioSRG-hall                         0.000000
# handleConfirmDeleteDesafioSRG-hall                  0.000000
# handleOpenPrezziModalSRG-hall                       0.002660
# handle-busc-semantica-hall                          0.000000
# onboarding-to Step 2                                0.000000
# onboarding-to Step 3                                0.000000
# onboarding-to Community                             0.000000
# modal-SRG                                           0.000000
# handleCloseDesafioModalSRG-hall                     0.034307
# ver canais-lxp                                      0.000000
# onboardingAdmin-skip                                0.000000
# criar conteúdo-lxp                                  0.000000
# handleViewDesafioSRG-hall                           0.000000
# onboarding-to Profile                               0.000000
# onboardingAdmin-to Step 2                           0.000000
# onboardingAdmin-to Step 3                           0.000000
# seta carrossel canais-lxp                           0.000000
# onboardingAdmin-to Step 4                           0.000000
# home-hall-manager                                   0.000000
# handleSkipPrezziSRG-hall                            0.000000
# onboarding-to Step 1                                0.000000
# onboarding-to Challenge                             0.000000
# clickNotification-hall                              0.000000
# botão carrossel meus desafios-hall                  0.003448
# handleEditDetaisSRG-hall                            0.000000
# click em módulos-lxp                                0.000000
# handleCancelDeleteDesafioSRG-hall                   0.000000
#
#                                     click em módulos-lxp  \
# home-hall                                       0.000000
# acessar conteúdos em vídeo-lxp                  0.007716
# click em trilhas-lxp                            0.000000
# acessar meus desafios-hall                      0.000000
# onboarding-skip                                 0.000000
# handleOpenModalSRG-hall                         0.000000
# handleDeleteDesafioSRG-hall                     0.000000
# handleConfirmDeleteDesafioSRG-hall              0.000000
# handleOpenPrezziModalSRG-hall                   0.000000
# handle-busc-semantica-hall                      0.000000
# onboarding-to Step 2                            0.000000
# onboarding-to Step 3                            0.000000
# onboarding-to Community                         0.000000
# modal-SRG                                       0.000000
# handleCloseDesafioModalSRG-hall                 0.000000
# ver canais-lxp                                  0.000000
# onboardingAdmin-skip                            0.000000
# criar conteúdo-lxp                              0.000000
# handleViewDesafioSRG-hall                       0.000000
# onboarding-to Profile                           0.000000
# onboardingAdmin-to Step 2                       0.000000
# onboardingAdmin-to Step 3                       0.000000
# seta carrossel canais-lxp                       0.015267
# onboardingAdmin-to Step 4                       0.000000
# home-hall-manager                               0.000000
# handleSkipPrezziSRG-hall                        0.000000
# onboarding-to Step 1                            0.000000
# onboarding-to Challenge                         0.000000
# clickNotification-hall                          0.000000
# botão carrossel meus desafios-hall              0.000000
# handleEditDetaisSRG-hall                        0.000000
# click em módulos-lxp                            0.046512
# handleCancelDeleteDesafioSRG-hall               0.000000
#
#                                     handleCancelDeleteDesafioSRG-hall
# home-hall                                                    0.000000
# acessar conteúdos em vídeo-lxp                               0.000000
# click em trilhas-lxp                                         0.000000
# acessar meus desafios-hall                                   0.000000
# onboarding-skip                                              0.000000
# handleOpenModalSRG-hall                                      0.000000
# handleDeleteDesafioSRG-hall                                  0.067416
# handleConfirmDeleteDesafioSRG-hall                           0.000000
# handleOpenPrezziModalSRG-hall                                0.000000
# handle-busc-semantica-hall                                   0.000000
# onboarding-to Step 2                                         0.000000
# onboarding-to Step 3                                         0.000000
# onboarding-to Community                                      0.000000
# modal-SRG                                                    0.000000
# handleCloseDesafioModalSRG-hall                              0.000000
# ver canais-lxp                                               0.000000
# onboardingAdmin-skip                                         0.000000
# criar conteúdo-lxp                                           0.000000
# handleViewDesafioSRG-hall                                    0.000000
# onboarding-to Profile                                        0.000000
# onboardingAdmin-to Step 2                                    0.000000
# onboardingAdmin-to Step 3                                    0.000000
# seta carrossel canais-lxp                                    0.000000
# onboardingAdmin-to Step 4                                    0.000000
# home-hall-manager                                            0.000000
# handleSkipPrezziSRG-hall                                     0.000000
# onboarding-to Step 1                                         0.000000
# onboarding-to Challenge                                      0.000000
# clickNotification-hall                                       0.000000
# botão carrossel meus desafios-hall                           0.000000
# handleEditDetaisSRG-hall                                     0.000000
# click em módulos-lxp                                         0.000000
# handleCancelDeleteDesafioSRG-hall                            0.000000
#
# [33 rows x 33 columns]

# %%
teste = list(matrix.loc['home-hall', :])
sum(teste)
# Out:
# 0.9999999999999999

# %% [markdown]
# # MONTE CARLO

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## TESTANDO

# %%
medias = []

for i in range(0,500):
    l_aux = random.choices(novo_path_list, k=2000)
    # l_aux = np.random.normal(loc=mean, scale=dp, size=20)
    medias.append(np.mean(l_aux))


mm = np.mean(medias)
upper = np.quantile(medias, 0.975)
lower = np.quantile(medias, 0.025)
print(mm, lower, upper)
# Out:
# 5.094506999999999 4.803875 5.389787500000001

# %%
sns.displot(medias)

plt.axvline(lower, color='red')
plt.axvline(upper, color='red')
plt.axvline(mm, color='green')
plt.show()

# %% [markdown]
# ## COMEÇO

# %%
originais = pd.read_excel('caminhos_originais.xlsx')
path_actions = df['path_actions']
contagem = {}
caminhos = originais['caminho']
repetidos = []
i = 0
for caminho in caminhos:
    for path in path_actions:
        if path == caminho:
            if originais['nome_caminho'][i] not in contagem.keys():
                contagem[originais['nome_caminho'][i]] = 1
            else:
                contagem[originais['nome_caminho'][i]] += 1
            repetidos.append(originais['nome_caminho'][i])
    i += 1
originais['contagem'] = contagem.values()

total = originais['contagem'].sum()
originais['contagem'] = originais['contagem']/total
pesos = originais['contagem']

# %%
originais
# Out:
#     Unnamed: 0 nome_caminho  \
# 0            0    caminho_0
# 1            1    caminho_1
# 2            2    caminho_4
# 3            3    caminho_5
# 4            4    caminho_6
# ..         ...          ...
# 59          59   caminho_70
# 60          60   caminho_71
# 61          61   caminho_72
# 62          62   caminho_73
# 63          63   caminho_74
#
#                                               caminho  contagem
# 0   ['home-hall', 'acessar conteúdos em vídeo-lxp'...  0.049917
# 1   ['onboardingAdmin-skip', 'home-hall', 'acessar...  0.026622
# 2   ['home-hall', 'acessar meus desafios-hall', 'h...  0.039933
# 3   ['home-hall', 'acessar conteúdos em vídeo-lxp'...  0.354409
# 4     ['home-hall', 'acessar conteúdos em vídeo-lxp']  0.038270
# ..                                                ...       ...
# 59  ['home-hall', 'acessar conteúdos em vídeo-lxp'...  0.006656
# 60  ['home-hall', 'acessar conteúdos em vídeo-lxp'...  0.008319
# 61  ['home-hall', 'home-hall', 'acessar meus desaf...  0.009983
# 62  ['home-hall', 'clickNotification-hall', 'home-...  0.006656
# 63  ['home-hall', 'acessar conteúdos em vídeo-lxp'...  0.004992
#
# [64 rows x 4 columns]

# %%
sns.set_theme(rc={
    
})
sns.displot(repetidos, height=10, aspect=2, kind='hist', stat='density')
plt.xticks(rotation=90)
plt.show()

# %%
modes = []

for i in range(0,50000):
    l_aux = random.choices(originais['caminho'], weights=pesos ,k=100)
    # modes.append(stats.mode(l_aux))


# mm = stats.mode(modes)
# upper = np.quantile(modes, 0.975)
# lower = np.quantile(modes, 0.025)
# print(mm)

# %%
sns.displot(l_aux, height=7, aspect=2, kind='hist', stat='density')
plt.xticks(rotation=90)
plt.show()

# %%
matrix.columns
# Out:
# Index(['home-hall', 'acessar conteúdos em vídeo-lxp', 'click em trilhas-lxp',
#        'acessar meus desafios-hall', 'onboarding-skip',
#        'handleOpenModalSRG-hall', 'handleDeleteDesafioSRG-hall',
#        'handleConfirmDeleteDesafioSRG-hall', 'handleOpenPrezziModalSRG-hall',
#        'handle-busc-semantica-hall', 'onboarding-to Step 2',
#        'onboarding-to Step 3', 'onboarding-to Community', 'modal-SRG',
#        'handleCloseDesafioModalSRG-hall', 'ver canais-lxp',
#        'onboardingAdmin-skip', 'criar conteúdo-lxp',
#        'handleViewDesafioSRG-hall', 'onboarding-to Profile',
#        'onboardingAdmin-to Step 2', 'onboardingAdmin-to Step 3',
#        'seta carrossel canais-lxp', 'onboardingAdmin-to Step 4',
#        'home-hall-manager', 'handleSkipPrezziSRG-hall', 'onboarding-to Step 1',
#        'onboarding-to Challenge', 'clickNotification-hall',
#        'botão carrossel meus desafios-hall', 'handleEditDetaisSRG-hall',
#        'click em módulos-lxp', 'handleCancelDeleteDesafioSRG-hall'],
#       dtype='object')

# %%
matrix_np = matrix.to_numpy()
Po = np.array([0]*33)
Po[0] = 1
home_hall_progresso = []
acessar_desafios_progresso = []
click_trilhas_progresso = []
acessar_conteudos_progresso = []
i = 0
for i in tqdm(range(1000000)):
    home_hall_progresso.append(Po[0])
    acessar_desafios_progresso.append(Po[3])
    click_trilhas_progresso.append(Po[2])
    acessar_conteudos_progresso.append(Po[1])

    Po = np.matmul(Po, matrix_np)

print(sum(Po))
print(Po)
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]100%|██████████| 1000000/1000000 [00:02<00:00, 360294.41it/s]
# 0.9999999999999977
# [1.76567057e-01 1.95666017e-01 5.88890427e-02 1.99321078e-01
#  7.92065450e-03 3.46691944e-02 2.86176324e-03 2.66883538e-03
#  1.12803814e-02 9.81427789e-03 1.83111370e-03 1.75317233e-03
#  1.85035783e-03 1.88599419e-01 2.69936481e-02 6.21818899e-03
#  2.66598817e-03 2.27125676e-03 2.70404849e-02 1.13559886e-03
#  7.88755205e-04 7.18188820e-04 4.74772921e-03 6.64678373e-04
#  2.76916836e-03 5.49036135e-03 1.56997276e-04 4.81400570e-04
#  9.75628465e-03 1.00573949e-02 2.49920329e-03 1.65937931e-03
#  1.92927859e-04]

# %%
df_progresso = pd.DataFrame({
    'Steps': np.arange(0,100,1),
    'Home Hall': home_hall_progresso[0:100],
    'Acessar conteudos': acessar_conteudos_progresso[0:100],
    'Clicar trilhas': click_trilhas_progresso[0:100],
    'Acessar desafios': acessar_desafios_progresso[0:100]
})

# %%
plt.figure(figsize=(15,7))
sns.lineplot(data=df_progresso[['Home Hall', 'Acessar conteudos', 'Clicar trilhas', 'Acessar desafios']])
plt.xlabel('Steps')
plt.ylabel('Prob')
plt.title('Prob VS Steps')
plt.show()

# %%
for i in range(0,50000):
    l_aux = random.choices(matrix.columns, weights=Po ,k=500)

# %%
plt.hist(l_aux)
# Out:
# (array([ 46., 105., 286.,  14.,  11.,  22.,   6.,   4.,   2.,   4.]),
#  array([ 0. ,  2.4,  4.8,  7.2,  9.6, 12. , 14.4, 16.8, 19.2, 21.6, 24. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.displot(l_aux, height=7, aspect=2, kind='hist', stat='density', kde=True)
plt.xticks(rotation=90)
plt.show()

# %%
sns.displot(paths_list_t, kind='hist', height=7, aspect=2, stat='density', kde=True)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # PI

# %%
x_list = [np.random.uniform(-1,1) for _ in range(100)]
y_list = [np.random.uniform(-1,1) for _ in range(100)]

# %%
red = []
red_x = []
red_y = []
all_x = []
all_y = []
all_points = []
i = 0
while i < len(x_list):

    if (x_list[i])**2 + (y_list[i])**2 <= 1:
        red_x.append(x_list[i])
        red_y.append(y_list[i])
        red.append((x_list[i], y_list[i]))
        
    all_points.append((x_list[i], y_list[i]))
    all_x.append(x_list[i])
    all_y.append(y_list[i])

    i += 1

# %%
plt.scatter(all_x, all_y, color='blue', alpha=0.2)
plt.scatter(red_x, red_y, color='red')

plt.xlim(-2,2)
plt.ylim(-2,2)
# Out:
# (-2.0, 2.0)

# %%
nRed = len(red_x)
nAll = len(all_x)
pi = 4 * (nRed/nAll)

print(pi)
# Out:
# 2.88
